# %%
# !pip install nba_api
# Out:
# ...
#      |████████████████████████████████| 125 kB 4.1 MB/s
# ...
#   Created wheel for nba-api: filename=nba_api-1.1.11-py3-none-any.whl size=251504 sha256=09a0e9f22662dcc11a454642b89dc58dc677cbb774376e2abe34ec47d11b76d9
#   Stored in directory: /root/.cache/pip/wheels/e3/f4/46/996128675381abc175e306642bae575d372dcf7efc4683e551
# Successfully built nba-api
# ...

# %%
from nba_api.stats.static import players
from nba_api.stats.static import teams
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.endpoints import playergamelog

# %%
active_players = players.get_active_players()

# %%
bane = next((player for player in active_players if player['full_name'] == 'Desmond Bane'),None)
barrett = next((player for player in active_players if player['full_name'] == 'RJ Barrett'),None)
dort = next((player for player in active_players if player['full_name'] == 'Luguentz Dort'),None)
brunson = next((player for player in active_players if player['full_name'] == 'Jalen Brunson'),None)
vucevic = next((player for player in active_players if player['full_name'] == 'Nikola Vucevic'),None)
trent = next((player for player in active_players if player['full_name'] == 'Gary Trent Jr.'),None)
embiid = next((player for player in active_players if player['full_name'] == 'Joel Embiid'),None)
doncic = next((player for player in active_players if player['full_name'] == 'Luka Doncic'),None)
garland = next((player for player in active_players if player['full_name'] == 'Darius Garland'),None)
bridges = next((player for player in active_players if player['full_name'] == 'Miles Bridges'),None)

# %%
vucevic['id'], trent['id']
# Out:
# (202696, 1629018)

# %%
player1_gamelog = playergamelog.PlayerGameLog(player_id=202696,season_type_all_star='Regular Season').get_data_frames()[0]
player1_gamelog
# Out:
#    SEASON_ID  Player_ID     Game_ID  ... PTS PLUS_MINUS VIDEO_AVAILABLE
# 0      22021     202696  0022100769  ...  18          2               1
# 1      22021     202696  0022100753  ...  24          9               1
# 2      22021     202696  0022100742  ...  18          1               1
# 3      22021     202696  0022100472  ...  17         20               1
# 4      22021     202696  0022100730  ...  26          8               1
# 5      22021     202696  0022100701  ...  13        -20               1
# 6      22021     202696  0022100690  ...  19          0               1
# 7      22021     202696  0022100673  ...  24         13               1
# 8      22021     202696  0022100658  ...   7        -16               1
# 9      22021     202696  0022100647  ...  27        -10               1
# 10     22021     202696  0022100637  ...  19        -21               1
# 11     22021     202696  0022100625  ...  14        -22               1
# ...

# %%
player2_gamelog = playergamelog.PlayerGameLog(player_id=1629018,season_type_all_star='Regular Season').get_data_frames()[0]
player2_gamelog
# Out:
#    SEASON_ID  Player_ID     Game_ID  ... PTS PLUS_MINUS VIDEO_AVAILABLE
# 0      22021    1629018  0022100784  ...  33          3               1
# 1      22021    1629018  0022100767  ...  31          8               1
# 2      22021    1629018  0022100748  ...  33          2               1
# 3      22021    1629018  0022100472  ...  32        -11               1
# 4      22021    1629018  0022100715  ...  32         12               1
# 5      22021    1629018  0022100702  ...  13        -10               1
# 6      22021    1629018  0022100689  ...  13         -1               1
# 7      22021    1629018  0022100584  ...  10         -5               1
# 8      22021    1629018  0022100573  ...  22         14               1
# 9      22021    1629018  0022100563  ...  21         14               1
# 10     22021    1629018  0022100545  ...   5         11               1
# 11     22021    1629018  0022100534  ...  10          3               1
# ...

# %% [markdown]
# Player 1's Stats vs that team

# %%
player1_gamelog[player1_gamelog['MATCHUP'].str.contains('CHA')]['PTS'].mean()
# Out:
# 30.0

# %% [markdown]
# Player 2's Stats vs that team

# %%
player2_gamelog[player2_gamelog['MATCHUP'].str.contains('CLE')]['PTS'].mean()
# Out:
# 17.0

# %% [markdown]
# Player 1's stats in last 5 games

# %%
player1_gamelog.head(5)['PTS'].mean()
# Out:
# 20.6

# %% [markdown]
# Player 2's stats in last 5 games

# %%
player2_gamelog.head(5)['PTS'].mean()
# Out:
# 32.2

# %% [markdown]
# SDs/ Ranges

# %% [markdown]
# Player 1

# %%
player1_gamelog['PTS'].std(), player1_gamelog['PTS'][0:5].std()
# Out:
# (5.763423831679039, 4.09878030638384)

# %%
player1_gamelog['PTS'].max() - player1_gamelog['PTS'].min(), player1_gamelog['PTS'][0:5].max() - player1_gamelog['PTS'][0:5].min()
# Out:
# (26, 9)

# %% [markdown]
# Player 2

# %%
player2_gamelog['PTS'].std(), player2_gamelog['PTS'][0:5].std()
# Out:
# (8.264497751038661, 0.8366600265340756)

# %%
player2_gamelog['PTS'].max() - player2_gamelog['PTS'].min(), player2_gamelog['PTS'][0:5].max() - player2_gamelog['PTS'][0:5].min()
# Out:
# (28, 2)
