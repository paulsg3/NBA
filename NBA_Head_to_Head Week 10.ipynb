# %%
# !pip install nba_api
# Out:
# ...
#      |████████████████████████████████| 125 kB 4.7 MB/s
# ...
#   Created wheel for nba-api: filename=nba_api-1.1.11-py3-none-any.whl size=251504 sha256=96144e2ff51fa750df1eda187d60467ddacd9b40066eb42728bb281bedc62376
#   Stored in directory: /root/.cache/pip/wheels/e3/f4/46/996128675381abc175e306642bae575d372dcf7efc4683e551
# Successfully built nba-api
# ...

# %%
from nba_api.stats.static import players
from nba_api.stats.static import teams
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.endpoints import playergamelog

# %%
active_players = players.get_active_players()

# %%
vucevic = next((player for player in active_players if player['full_name'] == 'Nikola Vucevic'),None)
rozier = next((player for player in active_players if player['full_name'] == 'Terry Rozier'),None)
og = next((player for player in active_players if player['full_name'] == 'OG Anunoby'),None)
dort = next((player for player in active_players if player['full_name'] == 'Luguentz Dort'),None)
curry = next((player for player in active_players if player['full_name'] == 'Stephen Curry'),None)
mitchell = next((player for player in active_players if player['full_name'] == 'Donovan Mitchell'),None)
adebayo = next((player for player in active_players if player['full_name'] == 'Bam Adebayo'),None)
valanciunas = next((player for player in active_players if player['full_name'] == 'Jonas Valanciunas'),None)
jokic = next((player for player in active_players if player['full_name'] == 'Nikola Jokic'),None)
tatum = next((player for player in active_players if player['full_name'] == 'Jayson Tatum'),None)

# %%
jokic['id'], tatum['id']
# Out:
# (203999, 1628369)

# %%
player1_gamelog = playergamelog.PlayerGameLog(player_id=203999,season_type_all_star='Regular Season').get_data_frames()[0]
player1_gamelog
# Out:
#    SEASON_ID  Player_ID     Game_ID  ... PTS PLUS_MINUS VIDEO_AVAILABLE
# 0      22021     203999  0022100804  ...  27         27               1
# 1      22021     203999  0022100794  ...  25         -6               1
# 2      22021     203999  0022100770  ...  21         -7               1
# 3      22021     203999  0022100756  ...  18         24               1
# 4      22021     203999  0022100729  ...  29         15               1
# 5      22021     203999  0022100453  ...  26          6               1
# 6      22021     203999  0022100714  ...  28         14               1
# 7      22021     203999  0022100707  ...  34         13               1
# 8      22021     203999  0022100692  ...  26          0               1
# 9      22021     203999  0022100678  ...  49         15               1
# 10     22021     203999  0022100653  ...  25          5               1
# 11     22021     203999  0022100649  ...  17         16               1
# ...

# %%
player2_gamelog = playergamelog.PlayerGameLog(player_id=1628369,season_type_all_star='Regular Season').get_data_frames()[0]
player2_gamelog
# Out:
#    SEASON_ID  Player_ID     Game_ID  ... PTS PLUS_MINUS VIDEO_AVAILABLE
# 0      22021    1628369  0022100806  ...  15         32               1
# 1      22021    1628369  0022100788  ...  24         14               1
# 2      22021    1628369  0022100775  ...  19          9               1
# 3      22021    1628369  0022100762  ...  20         30               1
# 4      22021    1628369  0022100745  ...  38         21               1
# 5      22021    1628369  0022100737  ...  20        -10               1
# 6      22021    1628369  0022100717  ...  36         36               1
# 7      22021    1628369  0022100699  ...  51         30               1
# 8      22021    1628369  0022100688  ...  27          2               1
# 9      22021    1628369  0022100671  ...  12         -7               1
# 10     22021    1628369  0022100654  ...  27         12               1
# 11     22021    1628369  0022100647  ...  23         11               1
# ...

# %% [markdown]
# Player 1's Stats vs that team

# %%
player1_gamelog[player1_gamelog['MATCHUP'].str.contains('BOS')]['PTS'].mean()
# Out:
# nan

# %% [markdown]
# Player 2's Stats vs that team

# %%
player2_gamelog[player2_gamelog['MATCHUP'].str.contains('DEN')]['PTS'].mean()
# Out:
# nan

# %% [markdown]
# Player 1's stats in last 5 games

# %%
player1_gamelog.head(5)['PTS'].mean()
# Out:
# 24.0

# %% [markdown]
# Player 2's stats in last 5 games

# %%
player2_gamelog.head(5)['PTS'].mean()
# Out:
# 23.2

# %% [markdown]
# Player 1 Overall Stats

# %%
(player1_gamelog[player1_gamelog['MATCHUP'].str.contains('UTA')]['PTS'].mean())*0.4 + (player1_gamelog.head(5)['PTS'].mean())* 0.6
# Out:
# 18.36

# %% [markdown]
# Player 2 Overall Stats

# %%
(player2_gamelog[player2_gamelog['MATCHUP'].str.contains('GSW')]['PTS'].mean())*0.4 + (player2_gamelog.head(5)['PTS'].mean())* 0.6
# Out:
# 15.32

# %% [markdown]
# SDs/ Ranges

# %% [markdown]
# Player 1

# %%
player1_gamelog['PTS'].std(), player1_gamelog['PTS'][0:5].std()
# Out:
# (9.628516673576119, 9.364827814754525)

# %%
player1_gamelog['PTS'].max() - player1_gamelog['PTS'].min(), player1_gamelog['PTS'][0:5].max() - player1_gamelog['PTS'][0:5].min()
# Out:
# (41, 22)

# %% [markdown]
# Player 2

# %%
player2_gamelog['PTS'].std(), player2_gamelog['PTS'][0:5].std()
# Out:
# (7.340127250967444, 8.54400374531753)

# %%
player2_gamelog['PTS'].max() - player2_gamelog['PTS'].min(), player2_gamelog['PTS'][0:5].max() - player2_gamelog['PTS'][0:5].min()
# Out:
# (26, 19)
